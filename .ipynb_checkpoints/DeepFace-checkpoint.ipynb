# %% [markdown]
# # DeepFace

# %% [markdown]
# https://docs.conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html?highlight=jupyter
#
# he extraido el environment principal a formato environment.yml como backup de my_python_21
#
# he limpiado el cache de anaconda
#     - conda clean -tipsy
#
# he creado un environment de 0
#
# instalado pip
#
# instalado deepface
#
# instalado ipywebrtc
#
# revisado kernels de jupyter y eliminado los innecesarios: jupyter kernelspec list
#
# instalado kernel en el env:
#     - conda install -c anaconda ipykernel
#     - python -m ipykernel install --user --name=firstEnv

# %%
from deepface import DeepFace

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pandas as pd

# %%
os.getcwd()
# Out:
# 'C:\\Users\\TC434LA\\OneDrive - EY\\Documents\\ME\\0- EY Courses\\FaceRecognitionSystem'

# %%
img_1 = 'faces/londres.jpg'
img_2 = 'faces/socor.jpg'
img_1_ocv = 'faces/opencv_frame_0.png'
img_3 = 'faces/tito.jpg'

# %%
plt.imshow(DeepFace.detectFace('faces_db/sopi.jpg',detector_backend='mtcnn', align=True))

# %%
plt.imshow(DeepFace.detectFace('faces_db/mum.jpg',detector_backend='mtcnn', align=True))

# %%
plt.imshow(DeepFace.detectFace(img_1_ocv,detector_backend='mtcnn', align=True))

# %%
plt.imshow(DeepFace.detectFace(img_1, enforce_detection=False, align=False))

# %%
plt.imshow(DeepFace.detectFace(img_2, enforce_detection=True, detector_backend='opencv', align=True))

# %%
plt.imshow(DeepFace.detectFace(img_2, enforce_detection=True, detector_backend='mtcnn', align=True))

# %%
plt.imshow(DeepFace.detectFace(img_2, enforce_detection=True, detector_backend='ssd', align=True))

# %%
plt.imshow(DeepFace.detectFace(img_3))

# %% [markdown]
# ---
# # Verify with 1 face

# %%
img1_path = [ # definición de parejas a comparar
                [img_1, img_2],
                [img_1, img_3]
        ]


ver_dic = DeepFace.verify(img1_path, model_name='Facenet',
                detector_backend='mtcnn', prog_bar=True)
# Out:
# Verification: 100%|██████████████████████████████████████████████████████████████████████| 2/2 [00:18<00:00,  9.18s/it]

# %%
ver_dic
# Out:
# {'pair_1': {'verified': True,
#   'distance': 0.24591210580940692,
#   'max_threshold_to_verify': 0.4,
#   'model': 'Facenet',
#   'similarity_metric': 'cosine'},
#  'pair_2': {'verified': False,
#   'distance': 1.146276324280242,
#   'max_threshold_to_verify': 0.4,
#   'model': 'Facenet',
#   'similarity_metric': 'cosine'}}

# %% [markdown]
# ---
# # Find if face in database

# %%
res = DeepFace.find(img_1, db_path="faces_db", 
              model_name='Facenet', prog_bar=True)
# Out:
# WARNING: Representations for images in  faces_db  folder were previously stored in  representations_facenet.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_facenet.pkl
# find function lasts  9.130804300308228  seconds

# %%
res.head()
# Out:
#            identity  Facenet_cosine
# 0  faces_db/gon.JPG   -4.440892e-16

# %% [markdown]
# ---
# # Find in Streaming

# %%
# imagenes deben estar con extensión .jpg (en minúsculas?)
DeepFace.stream(db_path = 'faces_db', model_name='VGG-Face', detector_backend='opencv', enable_face_analysis=False)
# Out:
# Detector backend is  opencv
# VGG-Face  is built
# Finding embedding for sopi.jpg: 100%|████████████████████████████████████████████████████| 3/3 [00:03<00:00,  1.21s/it]
# Embeddings found for given data set in  3.6427152156829834  seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22456/173476942.py in <module>
#       1 # imagenes deben estar con extensión .jpg (en minúsculas?)
# ----> 2 DeepFace.stream(db_path = 'faces_db', model_name='VGG-Face', detector_backend='opencv', enable_face_analysis=False)
#
# ~\Anaconda3\envs\deepface_venv\lib\site-packages\deepface\DeepFace.py in stream(db_path, model_name, detector_backend, distance_metric, enable_face_analysis, source, time_threshold, frame_threshold)
#     794                 raise ValueError("frame_threshold must be greater than the value 1 but you passed "+str(frame_threshold))
# ...

# %% [markdown]
# ---
# # ipywebrtc access camera test
#
# - camera stream https://github.com/QuantStack/quantstack-talks/blob/master/2018-11-14-PyParis-widgets/notebooks/6.ipywebrtc.ipynb
# - jupyter widgets important -> https://ipywidgets.readthedocs.io/en/stable/user_install.html#installing-the-jupyterlab-extension
# - ipywebrtc camera stream -> https://ipywebrtc.readthedocs.io/en/latest/api.html#ipywebrtc.webrtc.CameraStream

# %%
from ipywebrtc import CameraStream, ImageRecorder
# from IPython.display import display

# %%
camera = CameraStream(constraints=
                      {'facing_mode': 'user',
                       'audio': False,
                       'video': { 'width': 640, 'height': 480 }
                       })
camera
# Out:
# CameraStream(constraints={'facing_mode': 'user', 'audio': False, 'video': {'width': 640, 'height': 480}})

# %%
ImageRecorder(filename='record', autosave=True)
# Out:
# ImageRecorder(autosave=True, image=Image(value=b''), stream=None)

# %% [markdown]
# ---
# # OpenCV

# %%
import cv2

cam = cv2.VideoCapture(0)

cv2.namedWindow("test")

img_counter = 0

while True:
    ret, frame = cam.read()
    if not ret:
        print("failed to grab frame")
        break
    cv2.imshow("test", frame)

    k = cv2.waitKey(1)
    if k%256 == 27:
        # ESC pressed
        print("Escape hit, closing...")
        break
    elif k%256 == 32:
        # SPACE pressed
        img_name = "opencv_frame_{}.png".format(img_counter)
        cv2.imwrite(img_name, frame)
        print("{} written!".format(img_name))
        img_counter += 1
        break

cam.release()

cv2.destroyAllWindows()
# Out:
# opencv_frame_0.png written!

# %%
os.rename(img_name[:-3]+'jpg', img_name[:-3]+'png')

# %%
img = mpimg.imread(img_name)
plt.imshow(img)

# %%
res = DeepFace.find(img_name, db_path="faces_db", 
              model_name='Facenet', prog_bar=True)
if os.path.exists(img_name):
  os.remove(img_name)
else:
  print("The file does not exist")
# Out:
# WARNING: Representations for images in  faces_db  folder were previously stored in  representations_facenet.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_facenet.pkl
# find function lasts  0.43012309074401855  seconds

# %%
res
# Out:
#             identity  Facenet_cosine
# 0  faces_db/sopi.jpg        0.323739

# %%
res.identity[0].find('sopi')!=-1
# Out:
# True

# %%
res.identity[0].find('gon')!=-1
# Out:
# False
